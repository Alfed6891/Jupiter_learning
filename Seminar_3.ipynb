# %%
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv', encoding='1251') # encoding смена кодировки

# %%
df.sample(5)
# Out:
#      laptop_ID Company                                     Product
# 190        194  Lenovo                               Thinkpad Yoga  \
# 543        550    Acer                                    Aspire 7
# 839        848    Asus  R558UA-DM966T (i5-7200U/8GB/128GB/FHD/W10)
# 931        945      HP                               EliteBook 820
# 267        272  Lenovo                          IdeaPad 320-15IKBN
#
#                TypeName  Inches       ScreenResolution
# 190  2 in 1 Convertible    14.0  Touchscreen 2560x1440  \
# 543              Gaming    15.6      Full HD 1920x1080
# 839            Notebook    15.6      Full HD 1920x1080
# 931           Ultrabook    12.5      Full HD 1920x1080
# 267            Notebook    15.6      Full HD 1920x1080
#
#                              Cpu   Ram     Memory                      Gpu
# 190   Intel Core i7 7500U 2.7GHz  16GB    1TB SSD    Intel HD Graphics 620  \
# 543  Intel Core i5 7300HQ 2.5GHz   8GB    1TB HDD  Nvidia GeForce GTX 1050
# 839   Intel Core i5 7200U 2.5GHz   8GB  128GB HDD    Intel HD Graphics 620
# 931   Intel Core i5 6200U 2.3GHz   4GB  500GB HDD    Intel HD Graphics 520
# 267   Intel Core i5 7200U 2.5GHz   4GB    1TB HDD    Intel HD Graphics 620
#
#           OpSys  Weight  Price_euros
# 190  Windows 10  1.42kg       2824.0
# 543       Linux   2.4kg        798.0
# 839  Windows 10   2.3kg        590.0
# 931  Windows 10  1.26kg       1579.0
# 267       No OS   2.2kg        467.0

# %% [markdown]
# ## Задание 1
#
# Считать данные с помощью pandas
#
# Вывести на экран первые 5 строк

# %% [markdown]
# ### 1.1 Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU (Intel, AMD и т.д)

# %%
df['Cpu_Company'] = df['Cpu'].apply(lambda x: x.split()[0])

# %%
df.sample(5)
# Out:
#       laptop_ID Company                 Product            TypeName  Inches
# 824         833  Lenovo             ThinkPad X1           Ultrabook    14.0  \
# 1256       1274    Asus       Rog G752VT-GC073T              Gaming    17.3
# 322         327    Asus  ZenBook UX410UA-GV183T            Notebook    14.0
# 167         171    Dell           Inspiron 5577              Gaming    15.6
# 727         735    Dell           Inspiron 5378  2 in 1 Convertible    13.3
#
#                      ScreenResolution                          Cpu   Ram
# 824       IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8GB  \
# 1256      IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz  16GB
# 322                 Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
# 167                 Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz   8GB
# 727   Full HD / Touchscreen 1920x1080   Intel Core i3 7100U 2.4GHz   4GB
#
#                     Memory                      Gpu       OpSys  Weight
# 824    256GB Flash Storage    Intel HD Graphics 620  Windows 10  1.13kg  \
# 1256  128GB SSD +  1TB HDD  Nvidia GeForce GTX 970M  Windows 10   4.0kg
# 322              256GB SSD    Intel HD Graphics 620  Windows 10     2kg
# 167   128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050  Windows 10  2.56kg
# 727                1TB HDD    Intel HD Graphics 620  Windows 10  1.71kg
#
#       Price_euros Cpu_Company
# 824       1875.00       Intel
# 1256      1900.00       Intel
# 322       1094.00       Intel
# 167       1060.49       Intel
# 727        649.00       Intel

# %%
df['Cpu_Company'].value_counts()
# Out:
# Cpu_Company
# Intel      1240
# AMD          62
# Samsung       1
# Name: count, dtype: int64

# %% [markdown]
# ### 1.2 Создать новый признак Memory_Amount, который будет содержать только количество Gb памяти без указания типа носителя (128, 1024, 256 и т.д.)

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
# 512GB SSD +  1.0TB Hybrid  

def memory(row):
    row = row.split() 
    GB = 0
    for el in row:
        if 'GB' in el:
            GB += int(el[:-2])
        elif 'TB' in el:
            GB += float(el[:-2]) * 1024
    return int(GB)

# memory('512GB SSD +  1.0TB Hybrid')

# %%
df['Memory_Amount'] = df['Memory'].apply(memory)

# %%
df['Memory_Amount']
# Out:
# 0        128
# 1        128
# 2        256
# 3        512
# 4        256
#         ...
# 1298     128
# 1299     512
# 1300      64
# 1301    1024
# 1302     500
# Name: Memory_Amount, Length: 1303, dtype: int64

# %%
df.sample(5)
# Out:
#       laptop_ID    Company            Product   TypeName  Inches
# 458         465  Microsoft     Surface Laptop  Ultrabook    13.5  \
# 730         738       Acer        Predator 17     Gaming    17.3
# 838         847     Lenovo  N42-20 Chromebook   Notebook    14.0
# 1004       1018    Toshiba  Portege Z30-C-16H   Notebook    13.3
# 600         607         HP      EliteBook 850   Notebook    15.6
#
#                  ScreenResolution                                   Cpu   Ram
# 458         Touchscreen 2256x1504            Intel Core i7 7660U 2.5GHz   8GB  \
# 730   IPS Panel Full HD 1920x1080           Intel Core i7 6700HQ 2.6GHz  16GB
# 838                      1366x768  Intel Celeron Quad Core N3160 1.6GHz   4GB
# 1004            Full HD 1920x1080            Intel Core i5 6200U 2.3GHz   4GB
# 600             Full HD 1920x1080            Intel Core i7 7500U 2.7GHz   8GB
#
#                     Memory                           Gpu         OpSys
# 458              256GB SSD  Intel Iris Plus Graphics 640  Windows 10 S  \
# 730   128GB SSD +  1TB HDD       Nvidia GeForce GTX 1060    Windows 10
# 838     16GB Flash Storage         Intel HD Graphics 400     Chrome OS
# 1004             128GB SSD         Intel HD Graphics 520    Windows 10
# 600              256GB SSD         Intel HD Graphics 620    Windows 10
#
#       Weight  Price_euros Cpu_Company  Memory_Amount
# 458   1.25kg       1799.0       Intel            256
# 730    4.2kg       1935.0       Intel           1152
# 838    1.5kg        325.0       Intel             16
# 1004   1.2kg       1195.0       Intel            128
# 600   1.84kg       1219.0       Intel            256

# %% [markdown]
# ### 1.3 Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD, SDD и т.д.)

# %%
# 256GB SSD +  1.0TB Hybrid               
# 64GB Flash Storage +  1TB HDD 

def memory_type(row: str) -> str:
    row = row.split() 
    new_row = ''
    
    for el in row:
        if el.isalpha():
            if new_row:
                new_row += ' '
            new_row += el

    return new_row

memory_type('64GB Flash Storage +  1TB HDD')
# Out:
# 'Flash Storage HDD'

# %%
df['Memory_Type'] = df['Memory'].apply(memory_type)
df['Memory_Type'].value_counts()
# Out:
# Memory_Type
# SSD                  637
# HDD                  374
# SSD HDD              200
# Flash Storage         74
# Hybrid                10
# SSD SSD                4
# SSD Hybrid             2
# Flash Storage HDD      1
# HDD HDD                1
# Name: count, dtype: int64

# %% [markdown]
# ### 1.4 Удалите признаки Memory и ScreenResolution

# %%
df.drop(columns=['Memory', 'ScreenResolution'], inplace=True)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  \
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS  \
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type
# 0  1.37kg      1339.69       Intel            128            SSD
# 1  1.34kg       898.94       Intel            128  Flash Storage
# 2  1.86kg       575.00       Intel            256            SSD
# 3  1.83kg      2537.45       Intel            512            SSD
# 4  1.37kg      1803.60       Intel            256            SSD

# %% [markdown]
# # Задание 2.
# ### 2.1 Создайте признак SSD, который изначально равен 0

# %%
df['SSD'] = 0

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  \
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS  \
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type  SSD
# 0  1.37kg      1339.69       Intel            128            SSD    0
# 1  1.34kg       898.94       Intel            128  Flash Storage    0
# 2  1.86kg       575.00       Intel            256            SSD    0
# 3  1.83kg      2537.45       Intel            512            SSD    0
# 4  1.37kg      1803.60       Intel            256            SSD    0

# %% [markdown]
# ### 2.2 Поставьте в признаке SSD 1, если ноутбук действительно с типом носителя SSD

# %%
# df.loc[df['Memory_Type'] == 'SSD', 'SSD'] = 1

# %%
df.loc[df['Memory_Type'].str.contains('SSD'), 'SSD'] = 1

# %%
df.sample(15)
# Out:
#       laptop_ID Company                              Product
# 846         856      HP                      Chromebook X360  \
# 507         514    Acer                 Aspire A515-51G-59QF
# 216         221  Lenovo                    IdeaPad 320-17IKB
# 551         558    Dell                        Latitude 5580
# 790         799    Asus    FX502VM-DM560T (i7-7700HQ/8GB/1TB
# 990        1004      HP                      EliteBook Folio
# 342         348      HP                          ProBook 450
# 553         560      HP     17-X047na (i3-6006U/8GB/1TB/W10)
# 131         134    Dell                        Inspiron 3567
# 1265       1283  Lenovo                   IdeaPad Y700-15ISK
# 359         365    Dell                        Latitude 7480
# 4             5   Apple                          MacBook Pro
# 1176       1194  Lenovo  B51-80 (i7-6500U/4GB/1008GB/FHD/W7)
# 1160       1178  Lenovo                        ThinkPad T460
# 244         249  Lenovo                       Yoga 910-13IKB
#
#                 TypeName  Inches                                   Cpu  Ram
# 846   2 in 1 Convertible    11.6  Intel Celeron Dual Core N3350 1.1GHz  4GB  \
# 507             Notebook    15.6            Intel Core i5 8250U 1.6GHz  4GB
# 216             Notebook    17.3            Intel Core i5 7200U 2.5GHz  8GB
# 551             Notebook    15.6            Intel Core i5 7200U 2.5GHz  8GB
# 790               Gaming    15.6           Intel Core i7 7700HQ 2.8GHz  8GB
# 990              Netbook    12.5              Intel Core M 6Y75 1.2GHz  8GB
# 342             Notebook    15.6            Intel Core i3 7100U 2.4GHz  8GB
# 553             Notebook    17.3              Intel Core i3 6006U 2GHz  8GB
# 131             Notebook    15.6              Intel Core i3 6006U 2GHz  4GB
# 1265            Notebook    15.6           Intel Core i7 6700HQ 2.6GHz  8GB
# 359             Notebook    14.0            Intel Core i5 7300U 2.6GHz  8GB
# 4              Ultrabook    13.3                  Intel Core i5 3.1GHz  8GB
# 1176            Notebook    15.6            Intel Core i7 6500U 2.5GHz  4GB
# 1160           Ultrabook    14.0            Intel Core i7 6600U 2.6GHz  8GB
# 244   2 in 1 Convertible    13.9            Intel Core i7 7500U 2.7GHz  8GB
#
#                                Gpu       OpSys  Weight  Price_euros
# 846          Intel HD Graphics 500   Chrome OS   1.4kg       615.00  \
# 507           Nvidia GeForce MX150  Windows 10   2.2kg       613.00
# 216       Nvidia GeForce GTX 940MX       No OS   2.8kg       589.00
# 551          Intel HD Graphics 620  Windows 10   1.9kg      1116.99
# 790         Nvidia GeForce GTX1060  Windows 10  2.24kg      1339.00
# 990          Intel HD Graphics 515  Windows 10  0.97kg      1908.00
# 342          Nvidia GeForce 930MX   Windows 10   2.1kg       716.00
# 553          Intel HD Graphics 520  Windows 10  2.65kg       544.15
# 131             AMD Radeon R5 M430  Windows 10   2.2kg       449.00
# 1265       Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 359          Intel HD Graphics 620  Windows 10  1.36kg      1427.00
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# 1176         Intel HD Graphics 520   Windows 7  2.32kg       825.00
# 1160         Intel HD Graphics 520   Windows 7   1.7kg      1499.00
# 244          Intel HD Graphics 620  Windows 10  1.38kg      1079.00
#
#      Cpu_Company  Memory_Amount    Memory_Type  SSD
# 846        Intel             32  Flash Storage    0
# 507        Intel           1024            HDD    0
# 216        Intel           1024            HDD    0
# 551        Intel            256            SSD    1
# 790        Intel           1152        SSD HDD    1
# 990        Intel            512            SSD    1
# 342        Intel           1024            HDD    0
# 553        Intel           1024            HDD    0
# 131        Intel           1024            HDD    0
# 1265       Intel           1024            HDD    0
# 359        Intel            256            SSD    1
# 4          Intel            256            SSD    1
# 1176       Intel           1024         Hybrid    0
# 1160       Intel            256            SSD    1
# 244        Intel            256            SSD    1

# %% [markdown]
# ### 2.3 Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на вещественный

# %%
df['Weight'].value_counts()
# Out:
# Weight
# 2.2kg     121
# 2.1kg      58
# 2.4kg      44
# 2.3kg      41
# 2.5kg      38
#          ...
# 3.25kg      1
# 4.7kg       1
# 1.55kg      1
# 1.18kg      1
# 4.0kg       1
# Name: count, Length: 179, dtype: int64

# %%
df['Weight'] = df['Weight'].str.replace('kg','').astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   laptop_ID      1303 non-null   int64
#  1   Company        1303 non-null   object
#  2   Product        1303 non-null   object
#  3   TypeName       1303 non-null   object
#  4   Inches         1303 non-null   float64
#  5   Cpu            1303 non-null   object
#  6   Ram            1303 non-null   object
#  7   Gpu            1303 non-null   object
#  8   OpSys          1303 non-null   object
#  9   Weight         1303 non-null   float64
#  10  Price_euros    1303 non-null   float64
#  11  Cpu_Company    1303 non-null   object
#  12  Memory_Amount  1303 non-null   int64
#  13  Memory_Type    1303 non-null   object
#  14  SSD            1303 non-null   int64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 152.8+ KB

# %% [markdown]
# # Задание 3.
#
# Создайте датафрейм с клиентами:
#
#     clients = pd.DataFrame({
#         'client_id': [45, 32, 67, 33, 43],
#         'laptop_id': [506, 398, 710, 120, 1999]
#     })
#     laptop_id - это индексы датафрейма с ноутбуками

# %% [markdown]
# ### 3.1 Присоедините к таблице clients данные по ноутбукам через метод join

# %%
clients = pd.DataFrame({
    'client_id': [45, 32, 67, 33, 43],
    'laptop_id': [506, 398, 710, 120, 1999]
})

clients = clients.set_index('laptop_id')
clients
# Out:
#            client_id
# laptop_id
# 506               45
# 398               32
# 710               67
# 120               33
# 1999              43

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  \
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS  \
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type  SSD
# 0    1.37      1339.69       Intel            128            SSD    1
# 1    1.34       898.94       Intel            128  Flash Storage    0
# 2    1.86       575.00       Intel            256            SSD    1
# 3    1.83      2537.45       Intel            512            SSD    1
# 4    1.37      1803.60       Intel            256            SSD    1

# %%
df.rename(columns={'laptop_ID': 'laptop_id'}, inplace=True)
df.head()
# Out:
#    laptop_id Company      Product   TypeName  Inches
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  \
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS  \
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type  SSD
# 0    1.37      1339.69       Intel            128            SSD    1
# 1    1.34       898.94       Intel            128  Flash Storage    0
# 2    1.86       575.00       Intel            256            SSD    1
# 3    1.83      2537.45       Intel            512            SSD    1
# 4    1.37      1803.60       Intel            256            SSD    1

# %%
df.set_index('laptop_id', inplace=True)

# %%
df.head()
# Out:
#           Company      Product   TypeName  Inches                         Cpu
# laptop_id
# 1           Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz  \
# 2           Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz
# 3              HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz
# 4           Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz
# 5           Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz
#
#             Ram                           Gpu  OpSys  Weight  Price_euros
# laptop_id
# 1           8GB  Intel Iris Plus Graphics 640  macOS    1.37      1339.69  \
# 2           8GB        Intel HD Graphics 6000  macOS    1.34       898.94
# 3           8GB         Intel HD Graphics 620  No OS    1.86       575.00
# 4          16GB            AMD Radeon Pro 455  macOS    1.83      2537.45
# 5           8GB  Intel Iris Plus Graphics 650  macOS    1.37      1803.60
#
#           Cpu_Company  Memory_Amount    Memory_Type  SSD
# laptop_id
# 1               Intel            128            SSD    1
# 2               Intel            128  Flash Storage    0
# 3               Intel            256            SSD    1
# 4               Intel            512            SSD    1
# 5               Intel            256            SSD    1

# %%
df.join(clients, how='left')
# Out:
#           Company                              Product            TypeName
# laptop_id
# 1           Apple                          MacBook Pro           Ultrabook  \
# 2           Apple                          Macbook Air           Ultrabook
# 3              HP                               250 G6            Notebook
# 4           Apple                          MacBook Pro           Ultrabook
# 5           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1316       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1317       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1318       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1319           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1320         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#            Inches                                   Cpu   Ram
# laptop_id
# 1            13.3                  Intel Core i5 2.3GHz   8GB  \
# 2            13.3                  Intel Core i5 1.8GHz   8GB
# 3            15.6            Intel Core i5 7200U 2.5GHz   8GB
# 4            15.4                  Intel Core i7 2.7GHz  16GB
# 5            13.3                  Intel Core i5 3.1GHz   8GB
# ...           ...                                   ...   ...
# 1316         14.0            Intel Core i7 6500U 2.5GHz   4GB
# 1317         13.3            Intel Core i7 6500U 2.5GHz  16GB
# 1318         14.0  Intel Celeron Dual Core N3050 1.6GHz   2GB
# 1319         15.6            Intel Core i7 6500U 2.5GHz   6GB
# 1320         15.6  Intel Celeron Dual Core N3050 1.6GHz   4GB
#
#                                     Gpu       OpSys  Weight  Price_euros
# laptop_id
# 1          Intel Iris Plus Graphics 640       macOS    1.37      1339.69  \
# 2                Intel HD Graphics 6000       macOS    1.34       898.94
# 3                 Intel HD Graphics 620       No OS    1.86       575.00
# 4                    AMD Radeon Pro 455       macOS    1.83      2537.45
# 5          Intel Iris Plus Graphics 650       macOS    1.37      1803.60
# ...                                 ...         ...     ...          ...
# 1316              Intel HD Graphics 520  Windows 10    1.80       638.00
# 1317              Intel HD Graphics 520  Windows 10    1.30      1499.00
# 1318                  Intel HD Graphics  Windows 10    1.50       229.00
# 1319                 AMD Radeon R5 M330  Windows 10    2.19       764.00
# 1320                  Intel HD Graphics  Windows 10    2.20       369.00
#
#           Cpu_Company  Memory_Amount    Memory_Type  SSD  client_id
# laptop_id
# 1               Intel            128            SSD    1        NaN
# 2               Intel            128  Flash Storage    0        NaN
# 3               Intel            256            SSD    1        NaN
# 4               Intel            512            SSD    1        NaN
# 5               Intel            256            SSD    1        NaN
# ...               ...            ...            ...  ...        ...
# 1316            Intel            128            SSD    1        NaN
# 1317            Intel            512            SSD    1        NaN
# 1318            Intel             64  Flash Storage    0        NaN
# 1319            Intel           1024            HDD    0        NaN
# 1320            Intel            500            HDD    0        NaN
#
# [1303 rows x 15 columns]

# %% [markdown]
# ### 3.2 Присоедините к таблице clients данные по ноутбукам через метод merge
# Это нужно, чтобы понимать, какие ноутбуки покупались клиентами

# %%
clients.reset_index(inplace=True)
df.reset_index(inplace=True)

a = clients.merge(df, on='laptop_id', how='outer')

a.head()
# Out:
#    laptop_id  client_id Company            Product  TypeName  Inches
# 0        506       45.0  Lenovo      ThinkPad L570  Notebook    15.6  \
# 1        398       32.0     NaN                NaN       NaN     NaN
# 2        710       67.0  Lenovo  IdeaPad 320-15ABR  Notebook    15.6
# 3        120       33.0    Dell      Inspiron 7570  Notebook    15.6
# 4       1999       43.0     NaN                NaN       NaN     NaN
#
#                            Cpu  Ram                    Gpu       OpSys
# 0   Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620  Windows 10  \
# 1                          NaN  NaN                    NaN         NaN
# 2  AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7  Windows 10
# 3   Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX  Windows 10
# 4                          NaN  NaN                    NaN         NaN
#
#    Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  SSD
# 0    2.30       911.00       Intel          256.0         SSD  1.0
# 1     NaN          NaN         NaN            NaN         NaN  NaN
# 2    2.20       429.00         AMD         1024.0         HDD  0.0
# 3    2.16      1130.33       Intel         1280.0     SSD HDD  1.0
# 4     NaN          NaN         NaN            NaN         NaN  NaN

# %% [markdown]
# # Задание 4.
#
# Составьте несколько сводных таблиц
# ### 4.1 Найдите среднюю стоимость ноутбуков в зависимости от компании производителя
#
# Отсортируйте от меньшей стоимости к большей

# %%
df.head()
# Out:
#    laptop_id Company      Product   TypeName  Inches
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  \
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS  \
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type  SSD
# 0    1.37      1339.69       Intel            128            SSD    1
# 1    1.34       898.94       Intel            128  Flash Storage    0
# 2    1.86       575.00       Intel            256            SSD    1
# 3    1.83      2537.45       Intel            512            SSD    1
# 4    1.37      1803.60       Intel            256            SSD    1

# %%
df.groupby('Company').agg({'Price_euros':'mean'}).sort_values('Price_euros')
# Out:
#            Price_euros
# Company
# Vero        217.425000
# Mediacom    295.000000
# Chuwi       314.296667
# Acer        626.775825
# Fujitsu     729.000000
# HP         1067.774854
# Lenovo     1086.384444
# Asus       1104.169367
# Xiaomi     1133.462500
# Dell       1186.068990
# Toshiba    1267.812500
# Samsung    1413.444444
# Huawei     1424.000000
# Apple      1564.198571
# Microsoft  1612.308333
# Google     1677.666667
# MSI        1728.908148
# LG         2099.000000
# Razer      3346.142857

# %% [markdown]
# ### 4.2 Найдите минимальную, среднюю и максимальную стоимости ноутбуков в зависимости от производителя процессора

# %%
df.groupby('Cpu_Company').agg({'Price_euros':['min', 'mean', 'max']})
# Out:
#             Price_euros
#                     min         mean     max
# Cpu_Company
# AMD               199.0   560.638871  2199.0
# Intel             174.0  1152.214145  6099.0
# Samsung           659.0   659.000000   659.0

# %% [markdown]
# ### 4.3 Постройте таблицу с подсчетом количества ноутбуков в данных в зависимости от производителя CPU и ОЗУ

# %%
df.pivot_table(index='Cpu_Company',
               columns='Ram',
               values= 'Weight',
               aggfunc='count',
               fill_value=0)
# Out:
# Ram          12GB  16GB  24GB  2GB  32GB  4GB  64GB  6GB  8GB
# Cpu_Company
# AMD             2     3     0    1     0   31     0   13   12
# Intel          23   197     3   21    17  343     1   28  607
# Samsung         0     0     0    0     0    1     0    0    0

# %% [markdown]
# ### 4.4 Постройте таблицу с подсчетом средней стоимости ноутбуков в данных в зависимости от операционной системы и GB памяти

# %%
df.groupby(['OpSys', 'Memory_Amount']).agg({'Price_euros':'mean'}).unstack('Memory_Amount').fillna(0)
# Out:
#               Price_euros
# Memory_Amount        8       16          32          64           128
# OpSys
# Android               0.0    0.00    0.000000  434.000000     0.000000  \
# Chrome OS             0.0  305.38  412.454545  774.333333  1275.000000
# Linux                 0.0    0.00    0.000000    0.000000   490.500000
# Mac OS X              0.0    0.00    0.000000    0.000000  1099.000000
# No OS                 0.0    0.00    0.000000    0.000000   362.024000
# Windows 10         2249.0    0.00  270.001471  333.795556   673.385692
# Windows 10 S          0.0    0.00    0.000000  308.995000  1039.000000
# Windows 7             0.0    0.00    0.000000    0.000000  1320.323333
# macOS                 0.0    0.00    0.000000    0.000000  1119.315000
#
#                                                                 ...
# Memory_Amount    180     240          256         500     508   ...     768
# OpSys                                                           ...
# Android           0.0     0.0     0.000000    0.000000     0.0  ...     0.00  \
# Chrome OS         0.0     0.0  1559.000000    0.000000     0.0  ...     0.00
# Linux             0.0     0.0   795.814000  389.056364     0.0  ...     0.00
# Mac OS X          0.0     0.0  1311.994000    0.000000     0.0  ...     0.00
# No OS             0.0     0.0   754.834615  404.675385     0.0  ...     0.00
# Windows 10     1073.5  3100.0  1214.518551  664.717647     0.0  ...  1607.96
# Windows 10 S      0.0     0.0  1668.950000    0.000000     0.0  ...     0.00
# Windows 7      1199.0     0.0  1846.466800  924.048333  1002.0  ...     0.00
# macOS             0.0     0.0  1600.370000    0.000000     0.0  ...     0.00
#
#
# Memory_Amount         1024    1088         1152         1280         1536
# OpSys
# Android           0.000000     0.0     0.000000     0.000000     0.000000  \
# Chrome OS         0.000000     0.0     0.000000     0.000000     0.000000
# Linux           581.401290     0.0   994.000000     0.000000     0.000000
# Mac OS X          0.000000     0.0     0.000000     0.000000     0.000000
# No OS           540.539600     0.0   895.666667  1149.000000     0.000000
# Windows 10      880.695661  1993.0  1285.464494  1878.083562  2549.750667
# Windows 10 S      0.000000     0.0     0.000000     0.000000     0.000000
# Windows 7      1539.666667     0.0     0.000000     0.000000     0.000000
# macOS             0.000000     0.0     0.000000     0.000000     0.000000
#
#
# Memory_Amount         2048    2176         2304    2560
# OpSys
# Android           0.000000    0.00     0.000000     0.0
# Chrome OS         0.000000    0.00     0.000000     0.0
# Linux             0.000000    0.00  1049.000000     0.0
# Mac OS X          0.000000    0.00     0.000000     0.0
# No OS           594.000000    0.00     0.000000     0.0
# Windows 10     1058.201333  977.95  1590.015556  1849.0
# Windows 10 S      0.000000    0.00     0.000000     0.0
# Windows 7         0.000000    0.00     0.000000     0.0
# macOS             0.000000    0.00     0.000000     0.0
#
# [9 rows x 22 columns]

# %% [markdown]
# # Задание 5.
#
# Ответьте на несколько вопросов, используя методы группировки
# ### 5.1 Ноутбуков каких компаний и с каким процессором больше?

# %%
pd.crosstab(index=df['Company'],
            columns=df['Cpu_Company'])
# Out:
# Cpu_Company  AMD  Intel  Samsung
# Company
# Acer          10     93        0
# Apple          0     21        0
# Asus          11    147        0
# Chuwi          0      3        0
# Dell           0    297        0
# Fujitsu        0      3        0
# Google         0      3        0
# HP            25    249        0
# Huawei         0      2        0
# LG             0      3        0
# Lenovo        16    281        0
# MSI            0     54        0
# Mediacom       0      7        0
# Microsoft      0      6        0
# Razer          0      7        0
# Samsung        0      8        1
# Toshiba        0     48        0
# Vero           0      4        0
# Xiaomi         0      4        0

# %% [markdown]
# ### 5.2 С каким типом памяти и с каким объемом памяти больше ноутбуков?

# %%
pd.crosstab(index=df['Memory_Type'],
            columns=df['Memory_Amount']).max().max()
# Out:
# 412
